# %%
import sys
sys.path.insert(0, '..')

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from diaphanous import (
    REPORTS_PER_PLATFORM,
    combine_brands,
    ingest_reports_per_platform,
    show,
)

def logger(format: str, *args, **kwargs) -> None:
    print(format.format(*args, **kwargs))

data = ingest_reports_per_platform(REPORTS_PER_PLATFORM, logger=logger)
# Out:
# Skipping metadata
# ➖ Alphabet (no CSAM data)
# ✅ Amazon
# ➖ Apple (no CSAM data)
# ➖ Automattic (no CSAM data)
# ➖ Aylo (no CSAM data)
# ✅ Discord
# ✅ Facebook
# ✅ GitHub
# ✅ Google
# ✅ Instagram
# ✅ LinkedIn
# ➖ Meta (no CSAM data)
# ✅ Microsoft
# ➖ Omegle (no CSAM data)
# ✅ Pinterest
# ✅ Pornhub
# ➖ Quora (no CSAM data)
# ✅ Reddit
# ✅ Snap
# ➖ Telegram (no transparency disclosures)
# ✅ TikTok
# ➖ Tumblr (no CSAM data)
# ✅ Twitch
# ✅ Twitter
# ➖ WhatsApp (no CSAM data)
# ➖ Wikimedia (no transparency disclosures)
# ➖ Wordpress (no CSAM data)
# ✅ X
# ✅ YouTube
# ✅ NCMEC

# %%
ms = data.disclosures["Microsoft"]
ms["account_reversals"] = ms["accounts"] * ms["reinstated accounts"] / 100
ms = ms.drop(columns=["pieces", "proactively detected pieces", "reinstated accounts", "reports"])
show(ms, caption="Microsoft Raw Data")
ms = ms.groupby(ms.index.year).sum()
ms["percent_acounts_reversed"] = ms["account_reversals"] / ms["accounts"] * 100

fb = data.disclosures["Facebook"]
ig = data.disclosures["Instagram"]

META_ACTIONED = [
    "pieces (Child Nudity & Sexual Exploitation)",
    "pieces (Child Endangerment: Sexual Exploitation)",
]

META_APPEALS = [
    "appeals (Child Nudity & Sexual Exploitation)",
    "appeals (Child Endangerment: Sexual Exploitation)",
]

META_REVERSALS = [
    "reversals (Child Nudity & Sexual Exploitation)",
    "reversals (Child Endangerment: Sexual Exploitation)",
]

META_SELF_REVERSALS = [
    "reversals w/o appeal (Child Nudity & Sexual Exploitation)",
    "reversals w/o appeal (Child Endangerment: Sexual Exploitation)",
]

meta = pd.DataFrame(data={
    'actioned': fb[META_ACTIONED].sum(axis=1).groupby(fb.index.year).sum(),
    'appealed': fb[META_APPEALS].sum(axis=1).groupby(fb.index.year).sum(),
    'reversed': fb[META_REVERSALS].sum(axis=1).groupby(fb.index.year).sum(),
    'self_reversed': fb[META_SELF_REVERSALS].sum(axis=1).groupby(fb.index.year).sum(),
})

meta["actioned"] += ig[META_ACTIONED].sum(axis=1).groupby(ig.index.year).sum()
meta["appealed"] += ig[META_APPEALS].sum(axis=1).groupby(ig.index.year).sum()
meta["reversed"] += ig[META_REVERSALS].sum(axis=1).groupby(ig.index.year).sum()
meta["self_reversed"] += ig[META_SELF_REVERSALS].sum(axis=1).groupby(ig.index.year).sum()

meta["percent_pieces_appealed"] = meta["appealed"] / meta["actioned"] * 100
meta["percent_pieces_reversed"] = meta["reversed"] / meta["actioned"] * 100
meta["percent_pieces_self_reversed"] = meta["self_reversed"] / meta["actioned"] * 100
meta["percent_pieces_reversed_total"] = (
    (meta["reversed"] + meta["self_reversed"]) / meta["actioned"] * 100
)

# Sigh, Pinterest has periods at quarter and half-year resolution. So Pandas
# doesn't create a PeriodIndex. So index.year doesn't work. Hence we first
# reduce the data to just the cells we need, explicitly create a PeriodIndex,
# group and aggregate, and then compute percentage

pt = data.disclosures["Pinterest"][["accounts", "account appeals", "account reversals"]]
show(pt, caption="Pinterest Raw Data")
pt = pt[~pt["accounts"].isna()]
pt.index = pd.PeriodIndex(pt.index)
pt = pt[pt.index.year >= 2022]
pt = pt.groupby(pt.index.year).sum()
pt["percent_accounts_appealed"] = pt["account appeals"] / pt["accounts"] * 100
pt["percent_accounts_reversed"] = pt["account reversals"] / pt["accounts"] * 100

# Let's assemble the concise results. Pinterest's numbers are terrifying:

show(
    """
    <h1>False Positives for CSE</h1>

    <p>We can approximate the false positive rate by taking the fraction of
    pieces or accounts that were actioned for CSE or CSAM but then restored
    again, whether by the platform on its own initiative or after the user
    launched an appeal. Unfortunately, only Meta, Microsoft, and Pinterest
    report the necessary statistics. The table below shows the results.</p>
    """
)

show(f"<strong>Meta {fb.index.min()} to {fb.index.max()}</strong>")

show(pd.DataFrame({
        "Meta Appeals (% Pieces)": meta["percent_pieces_appealed"],
        "Meta Reversals After Appeal (% Pieces)": meta["percent_pieces_reversed"],
        "Meta Reversals w/o Appeals (% Pieces)": meta["percent_pieces_self_reversed"],
        "Meta Reversals (% Pieces)": meta["percent_pieces_reversed_total"],
        "Microsoft Reversals (% Accounts)": ms["percent_acounts_reversed"],
        "Pinterest Appeals (% Accounts)": pt["percent_accounts_appealed"],
        "Pinterest Reversals (% Accounts)": pt["percent_accounts_reversed"],
    }),
    caption="Percentage of Pieces/Accounts Restored",
    highlight_columns=[
        "Meta Reversals (% Pieces)",
        "Microsoft Reversals (% Accounts)",
        "Pinterest Reversals (% Accounts)",
    ]
)
# Out:
# <style type="text/css">
# #T_88a76 caption {
#   caption-side: top;
#   font-size: 1.1em;
#   margin-bottom: 2ex;
#   vertical-align: center;
#   font-style: italic;
# }
# #T_88a76 .level0 {
#   text-align: start;
# }
# #T_88a76  {
#   font-variant-numeric: tabular-nums;
#   margin-top: 0;
#   margin-bottom: 2.0em;
# }
# </style>
# <table id="T_88a76">
#   <caption>Microsoft Raw Data</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_88a76_level0_col0" class="col_heading level0 col0" >accounts</th>
#       <th id="T_88a76_level0_col1" class="col_heading level0 col1" >account_reversals</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >period</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_88a76_level0_row0" class="row_heading level0 row0" >2023-07</th>
#       <td id="T_88a76_row0_col0" class="data row0 col0" >⋯</td>
#       <td id="T_88a76_row0_col1" class="data row0 col1" >⋯</td>
#     </tr>
#     <tr>
#       <th id="T_88a76_level0_row1" class="row_heading level0 row1" >2023-07</th>
#       <td id="T_88a76_row1_col0" class="data row1 col0" >10,237</td>
#       <td id="T_88a76_row1_col1" class="data row1 col1" >81.90</td>
#     </tr>
#     <tr>
#       <th id="T_88a76_level0_row2" class="row_heading level0 row2" >2023-07</th>
#       <td id="T_88a76_row2_col0" class="data row2 col0" >⋯</td>
#       <td id="T_88a76_row2_col1" class="data row2 col1" >⋯</td>
#     </tr>
#     <tr>
#       <th id="T_88a76_level0_row3" class="row_heading level0 row3" >2023-01</th>
#       <td id="T_88a76_row3_col0" class="data row3 col0" >⋯</td>
#       <td id="T_88a76_row3_col1" class="data row3 col1" >⋯</td>
#     </tr>
#     <tr>
#       <th id="T_88a76_level0_row4" class="row_heading level0 row4" >2023-01</th>
#       <td id="T_88a76_row4_col0" class="data row4 col0" >7,456</td>
#       <td id="T_88a76_row4_col1" class="data row4 col1" >104.38</td>
#     </tr>
#     <tr>
#       <th id="T_88a76_level0_row5" class="row_heading level0 row5" >2023-01</th>
#       <td id="T_88a76_row5_col0" class="data row5 col0" >⋯</td>
#       <td id="T_88a76_row5_col1" class="data row5 col1" >⋯</td>
#     </tr>
#     <tr>
#       <th id="T_88a76_level0_row6" class="row_heading level0 row6" >2022-07</th>
#       <td id="T_88a76_row6_col0" class="data row6 col0" >⋯</td>
#       <td id="T_88a76_row6_col1" class="data row6 col1" >⋯</td>
#     </tr>
#     <tr>
#       <th id="T_88a76_level0_row7" class="row_heading level0 row7" >2022-07</th>
#       <td id="T_88a76_row7_col0" class="data row7 col0" >6,461</td>
#       <td id="T_88a76_row7_col1" class="data row7 col1" >103.38</td>
#     </tr>
#     <tr>
#       <th id="T_88a76_level0_row8" class="row_heading level0 row8" >2022-07</th>
#       <td id="T_88a76_row8_col0" class="data row8 col0" >⋯</td>
#       <td id="T_88a76_row8_col1" class="data row8 col1" >⋯</td>
#     </tr>
#     <tr>
#       <th id="T_88a76_level0_row9" class="row_heading level0 row9" >2022-01</th>
#       <td id="T_88a76_row9_col0" class="data row9 col0" >⋯</td>
#       <td id="T_88a76_row9_col1" class="data row9 col1" >⋯</td>
#     </tr>
#     <tr>
#       <th id="T_88a76_level0_row10" class="row_heading level0 row10" >2022-01</th>
#       <td id="T_88a76_row10_col0" class="data row10 col0" >10,207</td>
#       <td id="T_88a76_row10_col1" class="data row10 col1" >57.16</td>
#     </tr>
#     <tr>
#       <th id="T_88a76_level0_row11" class="row_heading level0 row11" >2022-01</th>
#       <td id="T_88a76_row11_col0" class="data row11 col0" >⋯</td>
#       <td id="T_88a76_row11_col1" class="data row11 col1" >⋯</td>
#     </tr>
#     <tr>
#       <th id="T_88a76_level0_row12" class="row_heading level0 row12" >2021-07</th>
#       <td id="T_88a76_row12_col0" class="data row12 col0" >⋯</td>
#       <td id="T_88a76_row12_col1" class="data row12 col1" >⋯</td>
#     </tr>
#     <tr>
#       <th id="T_88a76_level0_row13" class="row_heading level0 row13" >2021-07</th>
#       <td id="T_88a76_row13_col0" class="data row13 col0" >11,805</td>
#       <td id="T_88a76_row13_col1" class="data row13 col1" >4.72</td>
#     </tr>
#     <tr>
#       <th id="T_88a76_level0_row14" class="row_heading level0 row14" >2021-07</th>
#       <td id="T_88a76_row14_col0" class="data row14 col0" >⋯</td>
#       <td id="T_88a76_row14_col1" class="data row14 col1" >⋯</td>
#     </tr>
#     <tr>
#       <th id="T_88a76_level0_row15" class="row_heading level0 row15" >2021-01</th>
#       <td id="T_88a76_row15_col0" class="data row15 col0" >⋯</td>
#       <td id="T_88a76_row15_col1" class="data row15 col1" >⋯</td>
#     </tr>
#     <tr>
#       <th id="T_88a76_level0_row16" class="row_heading level0 row16" >2021-01</th>
#       <td id="T_88a76_row16_col0" class="data row16 col0" >18,568</td>
#       <td id="T_88a76_row16_col1" class="data row16 col1" >3.71</td>
#     </tr>
#     <tr>
#       <th id="T_88a76_level0_row17" class="row_heading level0 row17" >2021-01</th>
#       <td id="T_88a76_row17_col0" class="data row17 col0" >⋯</td>
#       <td id="T_88a76_row17_col1" class="data row17 col1" >⋯</td>
#     </tr>
#     <tr>
#       <th id="T_88a76_level0_row18" class="row_heading level0 row18" >2020-07</th>
#       <td id="T_88a76_row18_col0" class="data row18 col0" >⋯</td>
#       <td id="T_88a76_row18_col1" class="data row18 col1" >⋯</td>
#     </tr>
#     <tr>
#       <th id="T_88a76_level0_row19" class="row_heading level0 row19" >2020-07</th>
#       <td id="T_88a76_row19_col0" class="data row19 col0" >17,434</td>
#       <td id="T_88a76_row19_col1" class="data row19 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_88a76_level0_row20" class="row_heading level0 row20" >2020-07</th>
#       <td id="T_88a76_row20_col0" class="data row20 col0" >⋯</td>
#       <td id="T_88a76_row20_col1" class="data row20 col1" >⋯</td>
#     </tr>
#     <tr>
#       <th id="T_88a76_level0_row21" class="row_heading level0 row21" >2020-01</th>
#       <td id="T_88a76_row21_col0" class="data row21 col0" >⋯</td>
#       <td id="T_88a76_row21_col1" class="data row21 col1" >⋯</td>
#     </tr>
#     <tr>
#       <th id="T_88a76_level0_row22" class="row_heading level0 row22" >2020-01</th>
#       <td id="T_88a76_row22_col0" class="data row22 col0" >15,935</td>
#       <td id="T_88a76_row22_col1" class="data row22 col1" >1.59</td>
#     </tr>
#     <tr>
#       <th id="T_88a76_level0_row23" class="row_heading level0 row23" >2020-01</th>
#       <td id="T_88a76_row23_col0" class="data row23 col0" >⋯</td>
#       <td id="T_88a76_row23_col1" class="data row23 col1" >⋯</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_57b41 caption {
#   caption-side: top;
#   font-size: 1.1em;
#   margin-bottom: 2ex;
#   vertical-align: center;
#   font-style: italic;
# }
# #T_57b41 .level0 {
#   text-align: start;
# }
# #T_57b41  {
#   font-variant-numeric: tabular-nums;
#   margin-top: 0;
#   margin-bottom: 2.0em;
# }
# </style>
# <table id="T_57b41">
#   <caption>Pinterest Raw Data</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_57b41_level0_col0" class="col_heading level0 col0" >accounts</th>
#       <th id="T_57b41_level0_col1" class="col_heading level0 col1" >account appeals</th>
#       <th id="T_57b41_level0_col2" class="col_heading level0 col2" >account reversals</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >period</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_57b41_level0_row0" class="row_heading level0 row0" >2023Q4</th>
#       <td id="T_57b41_row0_col0" class="data row0 col0" >173,110</td>
#       <td id="T_57b41_row0_col1" class="data row0 col1" >27,499</td>
#       <td id="T_57b41_row0_col2" class="data row0 col2" >19,754</td>
#     </tr>
#     <tr>
#       <th id="T_57b41_level0_row1" class="row_heading level0 row1" >2023Q3</th>
#       <td id="T_57b41_row1_col0" class="data row1 col0" >244,258</td>
#       <td id="T_57b41_row1_col1" class="data row1 col1" >65,254</td>
#       <td id="T_57b41_row1_col2" class="data row1 col2" >49,854</td>
#     </tr>
#     <tr>
#       <th id="T_57b41_level0_row2" class="row_heading level0 row2" >2023-07</th>
#       <td id="T_57b41_row2_col0" class="data row2 col0" >⋯</td>
#       <td id="T_57b41_row2_col1" class="data row2 col1" >⋯</td>
#       <td id="T_57b41_row2_col2" class="data row2 col2" >⋯</td>
#     </tr>
#     <tr>
#       <th id="T_57b41_level0_row3" class="row_heading level0 row3" >2023Q2</th>
#       <td id="T_57b41_row3_col0" class="data row3 col0" >172,633</td>
#       <td id="T_57b41_row3_col1" class="data row3 col1" >20,136</td>
#       <td id="T_57b41_row3_col2" class="data row3 col2" >9,874</td>
#     </tr>
#     <tr>
#       <th id="T_57b41_level0_row4" class="row_heading level0 row4" >2023Q1</th>
#       <td id="T_57b41_row4_col0" class="data row4 col0" >63,761</td>
#       <td id="T_57b41_row4_col1" class="data row4 col1" >8,524</td>
#       <td id="T_57b41_row4_col2" class="data row4 col2" >3,925</td>
#     </tr>
#     <tr>
#       <th id="T_57b41_level0_row5" class="row_heading level0 row5" >2023-01</th>
#       <td id="T_57b41_row5_col0" class="data row5 col0" >⋯</td>
#       <td id="T_57b41_row5_col1" class="data row5 col1" >⋯</td>
#       <td id="T_57b41_row5_col2" class="data row5 col2" >⋯</td>
#     </tr>
#     <tr>
#       <th id="T_57b41_level0_row6" class="row_heading level0 row6" >2022Q4</th>
#       <td id="T_57b41_row6_col0" class="data row6 col0" >33,228</td>
#       <td id="T_57b41_row6_col1" class="data row6 col1" >5,731</td>
#       <td id="T_57b41_row6_col2" class="data row6 col2" >2,686</td>
#     </tr>
#     <tr>
#       <th id="T_57b41_level0_row7" class="row_heading level0 row7" >2022Q3</th>
#       <td id="T_57b41_row7_col0" class="data row7 col0" >21,033</td>
#       <td id="T_57b41_row7_col1" class="data row7 col1" >3,896</td>
#       <td id="T_57b41_row7_col2" class="data row7 col2" >2,053</td>
#     </tr>
#     <tr>
#       <th id="T_57b41_level0_row8" class="row_heading level0 row8" >2022-07</th>
#       <td id="T_57b41_row8_col0" class="data row8 col0" >⋯</td>
#       <td id="T_57b41_row8_col1" class="data row8 col1" >⋯</td>
#       <td id="T_57b41_row8_col2" class="data row8 col2" >⋯</td>
#     </tr>
#     <tr>
#       <th id="T_57b41_level0_row9" class="row_heading level0 row9" >2022Q2</th>
#       <td id="T_57b41_row9_col0" class="data row9 col0" >37,694</td>
#       <td id="T_57b41_row9_col1" class="data row9 col1" >7,467</td>
#       <td id="T_57b41_row9_col2" class="data row9 col2" >5,971</td>
#     </tr>
#     <tr>
#       <th id="T_57b41_level0_row10" class="row_heading level0 row10" >2022Q1</th>
#       <td id="T_57b41_row10_col0" class="data row10 col0" >10,743</td>
#       <td id="T_57b41_row10_col1" class="data row10 col1" >2,164</td>
#       <td id="T_57b41_row10_col2" class="data row10 col2" >1,169</td>
#     </tr>
#     <tr>
#       <th id="T_57b41_level0_row11" class="row_heading level0 row11" >2022-01</th>
#       <td id="T_57b41_row11_col0" class="data row11 col0" >⋯</td>
#       <td id="T_57b41_row11_col1" class="data row11 col1" >⋯</td>
#       <td id="T_57b41_row11_col2" class="data row11 col2" >⋯</td>
#     </tr>
#     <tr>
#       <th id="T_57b41_level0_row12" class="row_heading level0 row12" >2021Q4</th>
#       <td id="T_57b41_row12_col0" class="data row12 col0" >17,423</td>
#       <td id="T_57b41_row12_col1" class="data row12 col1" >3,110</td>
#       <td id="T_57b41_row12_col2" class="data row12 col2" >2,120</td>
#     </tr>
#     <tr>
#       <th id="T_57b41_level0_row13" class="row_heading level0 row13" >2021Q3</th>
#       <td id="T_57b41_row13_col0" class="data row13 col0" >28,289</td>
#       <td id="T_57b41_row13_col1" class="data row13 col1" >5,718</td>
#       <td id="T_57b41_row13_col2" class="data row13 col2" >4,305</td>
#     </tr>
#     <tr>
#       <th id="T_57b41_level0_row14" class="row_heading level0 row14" >2021-07</th>
#       <td id="T_57b41_row14_col0" class="data row14 col0" >⋯</td>
#       <td id="T_57b41_row14_col1" class="data row14 col1" >⋯</td>
#       <td id="T_57b41_row14_col2" class="data row14 col2" >⋯</td>
#     </tr>
#     <tr>
#       <th id="T_57b41_level0_row15" class="row_heading level0 row15" >2021-01</th>
#       <td id="T_57b41_row15_col0" class="data row15 col0" >⋯</td>
#       <td id="T_57b41_row15_col1" class="data row15 col1" >⋯</td>
#       <td id="T_57b41_row15_col2" class="data row15 col2" >⋯</td>
#     </tr>
#     <tr>
#       <th id="T_57b41_level0_row16" class="row_heading level0 row16" >2020-07</th>
#       <td id="T_57b41_row16_col0" class="data row16 col0" >⋯</td>
#       <td id="T_57b41_row16_col1" class="data row16 col1" >⋯</td>
#       <td id="T_57b41_row16_col2" class="data row16 col2" >⋯</td>
#     </tr>
#     <tr>
#       <th id="T_57b41_level0_row17" class="row_heading level0 row17" >2020-01</th>
#       <td id="T_57b41_row17_col0" class="data row17 col0" >⋯</td>
#       <td id="T_57b41_row17_col1" class="data row17 col1" >⋯</td>
#       <td id="T_57b41_row17_col2" class="data row17 col2" >⋯</td>
#     </tr>
#   </tbody>
# </table>
#     <h1>False Positives for CSE</h1>
#
#     <p>We can approximate the false positive rate by taking the fraction of
#     pieces or accounts that were actioned for CSE or CSAM but then restored
#     again, whether by the platform on its own initiative or after the user
#     launched an appeal. Unfortunately, only Meta, Microsoft, and Pinterest
#     report the necessary statistics. The table below shows the results.</p>
# <strong>Meta 2018Q3 to 2024Q2</strong>
# <style type="text/css">
# #T_63509 caption {
#   caption-side: top;
#   font-size: 1.1em;
#   margin-bottom: 2ex;
#   vertical-align: center;
#   font-style: italic;
# }
# #T_63509  {
#   font-variant-numeric: tabular-nums;
#   margin-top: 0;
#   margin-bottom: 2.0em;
# }
# #T_63509_row0_col3, #T_63509_row0_col4, #T_63509_row0_col6, #T_63509_row1_col3, #T_63509_row1_col4, #T_63509_row1_col6, #T_63509_row2_col3, #T_63509_row2_col4, #T_63509_row2_col6, #T_63509_row3_col3, #T_63509_row3_col4, #T_63509_row3_col6, #T_63509_row4_col3, #T_63509_row4_col4, #T_63509_row4_col6, #T_63509_row5_col3, #T_63509_row5_col4, #T_63509_row5_col6, #T_63509_row6_col3, #T_63509_row6_col4, #T_63509_row6_col6 {
#   background-color: #ffffb3;
# }
# </style>
# <table id="T_63509">
#   <caption>Percentage of Pieces/Accounts Restored</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_63509_level0_col0" class="col_heading level0 col0" >Meta Appeals (% Pieces)</th>
#       <th id="T_63509_level0_col1" class="col_heading level0 col1" >Meta Reversals After Appeal (% Pieces)</th>
#       <th id="T_63509_level0_col2" class="col_heading level0 col2" >Meta Reversals w/o Appeals (% Pieces)</th>
#       <th id="T_63509_level0_col3" class="col_heading level0 col3" >Meta Reversals (% Pieces)</th>
#       <th id="T_63509_level0_col4" class="col_heading level0 col4" >Microsoft Reversals (% Accounts)</th>
#       <th id="T_63509_level0_col5" class="col_heading level0 col5" >Pinterest Appeals (% Accounts)</th>
#       <th id="T_63509_level0_col6" class="col_heading level0 col6" >Pinterest Reversals (% Accounts)</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >period</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_63509_level0_row0" class="row_heading level0 row0" >2018</th>
#       <td id="T_63509_row0_col0" class="data row0 col0" >⋯</td>
#       <td id="T_63509_row0_col1" class="data row0 col1" >⋯</td>
#       <td id="T_63509_row0_col2" class="data row0 col2" >⋯</td>
#       <td id="T_63509_row0_col3" class="data row0 col3" >⋯</td>
#       <td id="T_63509_row0_col4" class="data row0 col4" >⋯</td>
#       <td id="T_63509_row0_col5" class="data row0 col5" >⋯</td>
#       <td id="T_63509_row0_col6" class="data row0 col6" >⋯</td>
#     </tr>
#     <tr>
#       <th id="T_63509_level0_row1" class="row_heading level0 row1" >2019</th>
#       <td id="T_63509_row1_col0" class="data row1 col0" >0.95025</td>
#       <td id="T_63509_row1_col1" class="data row1 col1" >0.083062</td>
#       <td id="T_63509_row1_col2" class="data row1 col2" >0.0323</td>
#       <td id="T_63509_row1_col3" class="data row1 col3" >0.1153</td>
#       <td id="T_63509_row1_col4" class="data row1 col4" >⋯</td>
#       <td id="T_63509_row1_col5" class="data row1 col5" >⋯</td>
#       <td id="T_63509_row1_col6" class="data row1 col6" >⋯</td>
#     </tr>
#     <tr>
#       <th id="T_63509_level0_row2" class="row_heading level0 row2" >2020</th>
#       <td id="T_63509_row2_col0" class="data row2 col0" >0.29143</td>
#       <td id="T_63509_row2_col1" class="data row2 col1" >0.051195</td>
#       <td id="T_63509_row2_col2" class="data row2 col2" >0.0226</td>
#       <td id="T_63509_row2_col3" class="data row2 col3" >0.0738</td>
#       <td id="T_63509_row2_col4" class="data row2 col4" >0.00478</td>
#       <td id="T_63509_row2_col5" class="data row2 col5" >⋯</td>
#       <td id="T_63509_row2_col6" class="data row2 col6" >⋯</td>
#     </tr>
#     <tr>
#       <th id="T_63509_level0_row3" class="row_heading level0 row3" >2021</th>
#       <td id="T_63509_row3_col0" class="data row3 col0" >0.00808</td>
#       <td id="T_63509_row3_col1" class="data row3 col1" >0.000577</td>
#       <td id="T_63509_row3_col2" class="data row3 col2" >0.3056</td>
#       <td id="T_63509_row3_col3" class="data row3 col3" >0.3062</td>
#       <td id="T_63509_row3_col4" class="data row3 col4" >0.02777</td>
#       <td id="T_63509_row3_col5" class="data row3 col5" >⋯</td>
#       <td id="T_63509_row3_col6" class="data row3 col6" >⋯</td>
#     </tr>
#     <tr>
#       <th id="T_63509_level0_row4" class="row_heading level0 row4" >2022</th>
#       <td id="T_63509_row4_col0" class="data row4 col0" >0.80851</td>
#       <td id="T_63509_row4_col1" class="data row4 col1" >0.008147</td>
#       <td id="T_63509_row4_col2" class="data row4 col2" >1.0859</td>
#       <td id="T_63509_row4_col3" class="data row4 col3" >1.0941</td>
#       <td id="T_63509_row4_col4" class="data row4 col4" >0.96313</td>
#       <td id="T_63509_row4_col5" class="data row4 col5" >18.8</td>
#       <td id="T_63509_row4_col6" class="data row4 col6" >11.6</td>
#     </tr>
#     <tr>
#       <th id="T_63509_level0_row5" class="row_heading level0 row5" >2023</th>
#       <td id="T_63509_row5_col0" class="data row5 col0" >2.65182</td>
#       <td id="T_63509_row5_col1" class="data row5 col1" >0.812006</td>
#       <td id="T_63509_row5_col2" class="data row5 col2" >2.3180</td>
#       <td id="T_63509_row5_col3" class="data row5 col3" >3.1300</td>
#       <td id="T_63509_row5_col4" class="data row5 col4" >1.05285</td>
#       <td id="T_63509_row5_col5" class="data row5 col5" >18.6</td>
#       <td id="T_63509_row5_col6" class="data row5 col6" >12.8</td>
#     </tr>
#     <tr>
#       <th id="T_63509_level0_row6" class="row_heading level0 row6" >2024</th>
#       <td id="T_63509_row6_col0" class="data row6 col0" >3.14392</td>
#       <td id="T_63509_row6_col1" class="data row6 col1" >0.886486</td>
#       <td id="T_63509_row6_col2" class="data row6 col2" >0.5010</td>
#       <td id="T_63509_row6_col3" class="data row6 col3" >1.3875</td>
#       <td id="T_63509_row6_col4" class="data row6 col4" >⋯</td>
#       <td id="T_63509_row6_col5" class="data row6 col5" >⋯</td>
#       <td id="T_63509_row6_col6" class="data row6 col6" >⋯</td>
#     </tr>
#   </tbody>
# </table>
