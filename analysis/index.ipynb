# %%
# %run 'reports.ipynb'
# Out:
# <h1>Overview of CyberTipline Reports</h1>
#     Per <a href="https://www.law.cornell.edu/uscode/text/18/2258A">18 US Code
#     §2258A</a>, a number of activities related to the sexual exploitation of
#     children must be reported to the National Center for Missing and Exploited
#     Children or NCMEC. The following overview of the reports is based on NCMEC's
#     <a
#     href="https://www.missingkids.org/content/dam/missingkids/pdfs/OJJDP-NCMEC-Transparency_2022-Calendar-Year.pdf">2022
#     Report to the Office of Juvenile Justice and Delinquency Prevention</a>.
# <h2>Number of Reports</h2>
#     NCMEC started its CyberTipline in 1998. Since then, the number of reports
#     has increased significantly, doubling in many but not nearly all years.
#     NCMEC has characterized this growth as exponential in the above transparency
#     report. Alas, I am not convinced that is the case. As the figure below
# ...

# %%
# %run 'population.ipynb'
# Out:
# The rpy2.ipython extension is already loaded. To reload it, use:
#   %reload_ext rpy2.ipython
# (0.9043716685081888, 0.8975662870668343, 0.9064924832012359)
# <style type="text/css">
# #T_40045  {
#   font-variant-numeric: tabular-nums;
#   margin-top: 0;
#   margin-bottom: 2.0em;
# }
# </style>
# <table id="T_40045">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_40045_level0_col0" class="col_heading level0 col0" >year</th>
#       <th id="T_40045_level0_col1" class="col_heading level0 col1" >reports</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_40045_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_40045_row0_col0" class="data row0 col0" >2,023</td>
#       <td id="T_40045_row0_col1" class="data row0 col1" >36,210,368</td>
#     </tr>
#     <tr>
#       <th id="T_40045_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_40045_row1_col0" class="data row1 col0" >2,022</td>
# ...

# %%
# %run 'reversal.ipynb'
# Out:
# Skipping metadata
# ➖ Alphabet (no CSAM data)
# ✅ Amazon
# ➖ Amino (no CSAM data)
# ➖ Apple (no CSAM data)
# ➖ Automattic (no CSAM data)
# ➖ Aylo (no CSAM data)
# ✅ Discord
# ✅ Facebook
# ✅ GitHub
# ✅ Google
# ➖ Imgur (no CSAM data)
# ✅ Instagram
# ➖ Kik (no CSAM data)
# ✅ LinkedIn
# ➖ MediaLab (no CSAM data)
# ✅ Meta
# ✅ Microsoft
# ➖ Omegle (no CSAM data)
# ✅ Pinterest
# ✅ Pornhub
# ➖ Quora (no CSAM data)
# ✅ Reddit
# ✅ Snap
# ➖ Telegram (no CSAM data)
# ➖ Threads (no CSAM data)
# ✅ TikTok
# ➖ Tumblr (no CSAM data)
# ✅ Twitch
# ✅ Twitter
# ➖ WhatsApp (no CSAM data)
# ➖ Wikimedia (no CSAM data)
# ➖ Wordpress (no CSAM data)
# ✅ X
# ✅ YouTube
# ✅ NCMEC
# <style type="text/css">
# #T_bafae caption {
#   caption-side: top;
#   font-size: 1.1em;
#   margin-bottom: 2ex;
#   vertical-align: center;
#   font-style: italic;
# }
# #T_bafae .level0 {
#   text-align: start;
# }
# #T_bafae  {
#   font-variant-numeric: tabular-nums;
#   margin-top: 0;
#   margin-bottom: 2.0em;
# }
# </style>
# ...

# %%
# %run 'projections.ipynb'
# Out:
# <style type="text/css">
# #T_b10db caption {
#   caption-side: top;
#   font-size: 1.1em;
#   margin-bottom: 2ex;
#   vertical-align: center;
#   font-style: italic;
# }
# #T_b10db  {
#   font-variant-numeric: tabular-nums;
#   margin-top: 0;
#   margin-bottom: 2.0em;
# }
# </style>
# <table id="T_b10db">
#   <caption>Informational v Actionable Reports</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >level_of_detail</th>
#       <th id="T_b10db_level0_col0" class="col_heading level0 col0" >actionable</th>
#       <th id="T_b10db_level0_col1" class="col_heading level0 col1" >informational</th>
#       <th id="T_b10db_level0_col2" class="col_heading level0 col2" >reports</th>
#       <th id="T_b10db_level0_col3" class="col_heading level0 col3" >act_pct</th>
#       <th id="T_b10db_level0_col4" class="col_heading level0 col4" >info_pct</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >year</th>
#       <th class="blank col0" >&nbsp;</th>
# ...

# %%
# %run 'platform.ipynb'
# Out:
# The rpy2.ipython extension is already loaded. To reload it, use:
#   %reload_ext rpy2.ipython
# <h1>CSAM Reports per Platform</h1>
# <h2>Ingesting Platform Disclosures</h2>
# Skipping metadata
# ➖ Alphabet (no CSAM data)
# ✅ Amazon
# ➖ Amino (no CSAM data)
# ➖ Apple (no CSAM data)
# ➖ Automattic (no CSAM data)
# ➖ Aylo (no CSAM data)
# ✅ Discord
# ✅ Facebook
# ✅ GitHub
# ✅ Google
# ➖ Imgur (no CSAM data)
# ✅ Instagram
# ➖ Kik (no CSAM data)
# ✅ LinkedIn
# ➖ MediaLab (no CSAM data)
# ✅ Meta
# ✅ Microsoft
# ➖ Omegle (no CSAM data)
# ✅ Pinterest
# ✅ Pornhub
# ➖ Quora (no CSAM data)
# ✅ Reddit
# ✅ Snap
# ➖ Telegram (no CSAM data)
# ➖ Threads (no CSAM data)
# ✅ TikTok
# ➖ Tumblr (no CSAM data)
# ✅ Twitch
# ✅ Twitter
# ➖ WhatsApp (no CSAM data)
# ➖ Wikimedia (no CSAM data)
# ➖ Wordpress (no CSAM data)
# ✅ X
# ✅ YouTube
# ✅ NCMEC
# <h2>An Overview of Platform Disclosures</h2>
# <style type="text/css">
# #T_cea2b caption {
#   caption-side: top;
#   font-size: 1.1em;
#   margin-bottom: 2ex;
# ...

# %%
# %run 'meta.ipynb'
# Out:
# <h1>Meta: Family Active People vs World Population</h1>
# <style type="text/css">
# #T_290a5 caption {
#   caption-side: top;
#   font-size: 1.1em;
#   margin-bottom: 2ex;
#   vertical-align: center;
#   font-style: italic;
# }
# #T_290a5  {
#   font-variant-numeric: tabular-nums;
#   margin-top: 0;
#   margin-bottom: 2.0em;
# }
# </style>
# <table id="T_290a5">
#   <caption>Daily and Monthly Active People as Percentage of World Population</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_290a5_level0_col0" class="col_heading level0 col0" >year</th>
#       <th id="T_290a5_level0_col1" class="col_heading level0 col1" >daily</th>
#       <th id="T_290a5_level0_col2" class="col_heading level0 col2" >monthly</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_290a5_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_290a5_row0_col0" class="data row0 col0" >2,024</td>
# ...

# %%
# %run 'united-states.ipynb'
# Out:
# <h1>The United States</h1>
# <style type="text/css">
# #T_e1d7f caption {
#   caption-side: top;
#   font-size: 1.1em;
#   margin-bottom: 2ex;
#   vertical-align: center;
#   font-style: italic;
# }
# #T_e1d7f .level0 {
#   text-align: start;
# }
# #T_e1d7f  {
#   font-variant-numeric: tabular-nums;
#   margin-top: 0;
#   margin-bottom: 2.0em;
# }
# </style>
# <table id="T_e1d7f">
#   <caption>CyberTipline reports about incidents in US</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e1d7f_level0_col0" class="col_heading level0 col0" >reports</th>
#       <th id="T_e1d7f_level0_col1" class="col_heading level0 col1" >reports_pct</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >year</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e1d7f_level0_row0" class="row_heading level0 row0" >2019</th>
# ...

# %%
# %run 'country.ipynb'
# Out:
# <h1>CyberTipline Reports per Country</h1>
# <h2>Data Schemas</h2>
# <style type="text/css">
# #T_15aeb caption {
#   caption-side: top;
#   font-size: 1.1em;
#   margin-bottom: 2ex;
#   vertical-align: center;
# }
# #T_15aeb .col0 {
#   text-align: start;
# }
# #T_15aeb .col1 {
#   text-align: start;
# }
# #T_15aeb .col2 {
#   text-align: start;
# }
# #T_15aeb .col3 {
#   text-align: start;
# }
# #T_15aeb  {
#   font-variant-numeric: tabular-nums;
#   margin-top: 0;
#   margin-bottom: 2em;
# }
# #T_15aeb td {
#   padding: 0.1em 1ex 0.1em 0;
# }
# #T_15aeb td:nth-child(5) {
#   padding-left: 0.4em;
#   text-align: start;
# }
# </style>
# <table id="T_15aeb">
#   <caption><strong>reports</strong> with 1500 rows</caption>
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_15aeb_row0_col0" class="data row0 col0" >index</td>
#       <td id="T_15aeb_row0_col1" class="data row0 col1" >iso3</td>
#       <td id="T_15aeb_row0_col2" class="data row0 col2" >:</td>
# ...

# %%
# %run 'tiktok.ipynb'
# Out:
# <h1>TikTok</h1>
# <h2>2022Q4 to 2023Q1</h2>
# <style type="text/css">
# #T_a137c .col0 {
#   text-align: start;
# }
# #T_a137c  {
#   font-variant-numeric: tabular-nums;
#   margin-top: 0;
#   margin-bottom: 2.0em;
# }
# </style>
# <table id="T_a137c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a137c_level0_col0" class="col_heading level0 col0" >dataset</th>
#       <th id="T_a137c_level0_col1" class="col_heading level0 col1" >rows</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a137c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a137c_row0_col0" class="data row0 col0" >2022Q4</td>
#       <td id="T_a137c_row0_col1" class="data row0 col1" >1,030</td>
#     </tr>
#     <tr>
#       <th id="T_a137c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a137c_row1_col0" class="data row1 col0" >2023Q1</td>
#       <td id="T_a137c_row1_col1" class="data row1 col1" >1,522</td>
# ...
