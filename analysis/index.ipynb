# %%
# %run 'reports.ipynb'
# Out:
# <h1>Overview of CyberTipline Reports</h1>
#     Per <a href="https://www.law.cornell.edu/uscode/text/18/2258A">18 US Code
#     §2258A</a>, a number of activities related to the sexual exploitation of
#     children must be reported to the National Center for Missing and Exploited
#     Children or NCMEC. The following overview of the reports is based on NCMEC's
#     <a
#     href="https://www.missingkids.org/content/dam/missingkids/pdfs/OJJDP-NCMEC-Transparency_2022-Calendar-Year.pdf">2022
#     Report to the Office of Juvenile Justice and Delinquency Prevention</a>.
# <h2>Number of Reports</h2>
#     NCMEC started its CyberTipline in 1998. Since then, the number of reports
#     has increased significantly, doubling in many but not nearly all years.
#     NCMEC has characterized this growth as exponential in the above transparency
#     report. Alas, I am not convinced that is the case. As the figure below
# ...

# %%
# %run 'population.ipynb'
# Out:
# The rpy2.ipython extension is already loaded. To reload it, use:
#   %reload_ext rpy2.ipython
# <style type="text/css">
# #T_30a3f  {
#   font-variant-numeric: tabular-nums;
#   margin-top: 0;
#   margin-bottom: 2.0em;
# }
# </style>
# <table id="T_30a3f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_30a3f_level0_col0" class="col_heading level0 col0" >year</th>
#       <th id="T_30a3f_level0_col1" class="col_heading level0 col1" >reports</th>
#       <th id="T_30a3f_level0_col2" class="col_heading level0 col2" >population</th>
#       <th id="T_30a3f_level0_col3" class="col_heading level0 col3" >accounts</th>
#       <th id="T_30a3f_level0_col4" class="col_heading level0 col4" >internet_users</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_30a3f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_30a3f_row0_col0" class="data row0 col0" >2,023</td>
# ...

# %%
# %run 'reversal.ipynb'
# Out:
# Skipping metadata
# ➖ Alphabet (no CSAM data)
# ✅ Amazon
# ➖ Amino (no transparency disclosures)
# ➖ Apple (no CSAM data)
# ➖ Automattic (no CSAM data)
# ➖ Aylo (no CSAM data)
# ✅ Discord
# ✅ Facebook
# ✅ GitHub
# ✅ Google
# ➖ Imgur (no transparency disclosures)
# ✅ Instagram
# ➖ Kik (no transparency disclosures)
# ✅ LinkedIn
# ➖ MediaLab (no CSAM data)
# ➖ Meta (no CSAM data)
# ✅ Microsoft
# ➖ Omegle (no CSAM data)
# ✅ Pinterest
# ✅ Pornhub
# ➖ Quora (no CSAM data)
# ✅ Reddit
# ✅ Snap
# ➖ Telegram (no transparency disclosures)
# ➖ Threads (no CSAM data)
# ✅ TikTok
# ➖ Tumblr (no CSAM data)
# ✅ Twitch
# ✅ Twitter
# ➖ WhatsApp (no CSAM data)
# ➖ Wikimedia (no transparency disclosures)
# ➖ Wordpress (no CSAM data)
# ✅ X
# ✅ YouTube
# ✅ NCMEC
# <style type="text/css">
# #T_1abd2 caption {
#   caption-side: top;
#   font-size: 1.1em;
#   margin-bottom: 2ex;
#   vertical-align: center;
#   font-style: italic;
# }
# #T_1abd2 .level0 {
#   text-align: start;
# }
# #T_1abd2  {
# ...

# %%
# %run 'recipients.ipynb'
# Out:
# <style type="text/css">
# #T_e00ca .level1 {
#   text-align: start;
# }
# #T_e00ca  {
#   font-variant-numeric: tabular-nums;
#   margin-top: 0;
#   margin-bottom: 2.0em;
# }
# </style>
# <table id="T_e00ca">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e00ca_level0_col0" class="col_heading level0 col0" >reports</th>
#       <th id="T_e00ca_level0_col1" class="col_heading level0 col1" >totals</th>
#       <th id="T_e00ca_level0_col2" class="col_heading level0 col2" >reports_pct</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >year</th>
#       <th class="index_name level1" >level_of_detail</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e00ca_level0_row0" class="row_heading level0 row0" rowspan="2">2020</th>
# ...

# %%
# %run 'platform.ipynb'
# Out:
# The rpy2.ipython extension is already loaded. To reload it, use:
#   %reload_ext rpy2.ipython
# <h1>CSAM Reports per Platform</h1>
# <h2>Ingesting Platform Disclosures</h2>
# Skipping metadata
# ➖ Alphabet (no CSAM data)
# ✅ Amazon
# ➖ Amino (no transparency disclosures)
# ➖ Apple (no CSAM data)
# ➖ Automattic (no CSAM data)
# ➖ Aylo (no CSAM data)
# ✅ Discord
# ✅ Facebook
# ✅ GitHub
# ✅ Google
# ➖ Imgur (no transparency disclosures)
# ✅ Instagram
# ➖ Kik (no transparency disclosures)
# ✅ LinkedIn
# ➖ MediaLab (no CSAM data)
# ➖ Meta (no CSAM data)
# ✅ Microsoft
# ➖ Omegle (no CSAM data)
# ✅ Pinterest
# ✅ Pornhub
# ➖ Quora (no CSAM data)
# ✅ Reddit
# ✅ Snap
# ➖ Telegram (no transparency disclosures)
# ➖ Threads (no CSAM data)
# ✅ TikTok
# ➖ Tumblr (no CSAM data)
# ✅ Twitch
# ✅ Twitter
# ➖ WhatsApp (no CSAM data)
# ➖ Wikimedia (no transparency disclosures)
# ➖ Wordpress (no CSAM data)
# ✅ X
# ✅ YouTube
# ✅ NCMEC
# <h2>An Overview of Platform Disclosures</h2>
# <style type="text/css">
# ...

# %%
# %run 'meta.ipynb'
# Out:
# <h1>Meta: Family Active People vs World Population</h1>
# <style type="text/css">
# #T_581dc caption {
#   caption-side: top;
#   font-size: 1.1em;
#   margin-bottom: 2ex;
#   vertical-align: center;
#   font-style: italic;
# }
# #T_581dc  {
#   font-variant-numeric: tabular-nums;
#   margin-top: 0;
#   margin-bottom: 2.0em;
# }
# </style>
# <table id="T_581dc">
#   <caption>Daily and Monthly Active People as Percentage of World Population</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_581dc_level0_col0" class="col_heading level0 col0" >year</th>
#       <th id="T_581dc_level0_col1" class="col_heading level0 col1" >daily</th>
#       <th id="T_581dc_level0_col2" class="col_heading level0 col2" >monthly</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_581dc_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_581dc_row0_col0" class="data row0 col0" >2,024</td>
# ...

# %%
# %run 'united-states.ipynb'
# Out:
# <h1>The United States</h1>
# <style type="text/css">
# #T_ea1d3 caption {
#   caption-side: top;
#   font-size: 1.1em;
#   margin-bottom: 2ex;
#   vertical-align: center;
#   font-style: italic;
# }
# #T_ea1d3 .level0 {
#   text-align: start;
# }
# #T_ea1d3  {
#   font-variant-numeric: tabular-nums;
#   margin-top: 0;
#   margin-bottom: 2.0em;
# }
# </style>
# <table id="T_ea1d3">
#   <caption>CyberTipline reports about incidents in US</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ea1d3_level0_col0" class="col_heading level0 col0" >reports</th>
#       <th id="T_ea1d3_level0_col1" class="col_heading level0 col1" >reports_pct</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >year</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ea1d3_level0_row0" class="row_heading level0 row0" >2019</th>
# ...

# %%
# %run 'country.ipynb'
# Out:
# <h1>CyberTipline Reports per Country</h1>
# <h2>Data Schemas</h2>
# <style type="text/css">
# #T_2f35c caption {
#   caption-side: top;
#   font-size: 1.1em;
#   margin-bottom: 2ex;
#   vertical-align: center;
# }
# #T_2f35c .col0 {
#   text-align: start;
# }
# #T_2f35c .col1 {
#   text-align: start;
# }
# #T_2f35c .col2 {
#   text-align: start;
# }
# #T_2f35c .col3 {
#   text-align: start;
# }
# #T_2f35c  {
#   font-variant-numeric: tabular-nums;
#   margin-top: 0;
#   margin-bottom: 2em;
# }
# #T_2f35c td {
#   padding: 0.1em 1ex 0.1em 0;
# }
# #T_2f35c td:nth-child(5) {
#   padding-left: 0.4em;
#   text-align: start;
# }
# </style>
# <table id="T_2f35c">
#   <caption><strong>reports</strong> with 1250 rows</caption>
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_2f35c_row0_col0" class="data row0 col0" >index</td>
#       <td id="T_2f35c_row0_col1" class="data row0 col1" >iso3</td>
#       <td id="T_2f35c_row0_col2" class="data row0 col2" >:</td>
# ...

# %%
# %run 'tiktok.ipynb'
# Out:
# <h1>TikTok</h1>
# <h2>2022Q4 to 2023Q1</h2>
# <style type="text/css">
# #T_7d5c3 .col0 {
#   text-align: start;
# }
# #T_7d5c3  {
#   font-variant-numeric: tabular-nums;
#   margin-top: 0;
#   margin-bottom: 2.0em;
# }
# </style>
# <table id="T_7d5c3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7d5c3_level0_col0" class="col_heading level0 col0" >dataset</th>
#       <th id="T_7d5c3_level0_col1" class="col_heading level0 col1" >rows</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7d5c3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7d5c3_row0_col0" class="data row0 col0" >2022Q4</td>
#       <td id="T_7d5c3_row0_col1" class="data row0 col1" >1,030</td>
#     </tr>
#     <tr>
#       <th id="T_7d5c3_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7d5c3_row1_col0" class="data row1 col0" >2023Q1</td>
#       <td id="T_7d5c3_row1_col1" class="data row1 col1" >1,522</td>
# ...
